# %%
from PIL import Image
from util import *

# %%
ref_img = Image.open(r'C:/Users/q3357/Pictures/GQl6fs_akAAMzef.jpg')
ref_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=680x680>

# %%
prompt = '1girl, green hair, manga style, white background, best quality'
batch_size = 3

# %%
import matplotlib.pyplot as plt

output = cnet_txt2img(prompt=prompt, ref_img=ref_img, module='canny', batch_size=batch_size)

fig, axes = plt.subplots(1, len(output), figsize=(15, 5))
for ax, img in zip(axes, output):
    ax.imshow(img)
    ax.axis('off')

plt.show()

# %%
from PIL import Image
from util import *

# %%
image = Image.open(r'C:/Users/q3357/Pictures/o_1etf4c1v5uif1apu9hi1prl1gnl0.png')
mask = Image.open(r'C:/Users/q3357/Pictures/mask.png')

import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(15, 5))
for ax, img in zip(axes, [image, mask]):
    ax.imshow(img)
    ax.axis('off')

plt.show()

# %%
prompt = 'cat on sofa'
batch_size = 3

output = img2img_inpaint(prompt=prompt, img=image, mask=mask, batch_size=batch_size)

fig, axes = plt.subplots(1, len(output), figsize=(15, 5))
for ax, img in zip(axes, output):
    ax.imshow(img)
    ax.axis('off')

plt.show()
